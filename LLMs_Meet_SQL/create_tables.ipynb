# %%
# %reset -f

# %%
# %config SqlMagic.style = 'DEFAULT'

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Create MySQL connection string
# %sql mysql+pymysql://root:Chicago_2145@localhost/

# %sql mysql+pymysql://root@localhost/

# %%
# Cell 4 - Method 1: Using single-line SQL
# %sql CREATE DATABASE IF NOT EXISTS SalesOrderSchema;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 1 rows affected.
# []

# %%
# Fourth cell: Use the database
# %sql USE SalesOrderSchema;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 0 rows affected.
# []

# %%
# Fifth cell: Create your tables
# %sql CREATE TABLE Customer ( CustomerID INT AUTO_INCREMENT PRIMARY KEY, \
    FirstName VARCHAR(100), \
    LastName VARCHAR(100), \
    Email VARCHAR(255), \
    Phone VARCHAR(20), \
    BillingAddress TEXT, \
    ShippingAddress TEXT, \
    CustomerSince DATE, \
    IsActive BOOLEAN \
);

# %sql CREATE TABLE SalesOrder ( \
  SalesOrderID INT AUTO_INCREMENT PRIMARY KEY, \
  CustomerID INT, \
  OrderDate DATE, \
  RequiredDate DATE, \
  ShippedDate DATE, \
  Status VARCHAR(50), \
  Comments TEXT, \
  PaymentMethod VARCHAR(50), \
  IsPaid BOOLEAN, \
  FOREIGN KEY (CustomerID) REFERENCES Customer(CustomerID) \
);

# %sql CREATE TABLE Product ( \
  ProductID INT AUTO_INCREMENT PRIMARY KEY, \
  ProductName VARCHAR(255), \
  Description TEXT, \
  UnitPrice DECIMAL(10, 2), \
  StockQuantity INT, \
  ReorderLevel INT, \
  Discontinued BOOLEAN \
);
# Out:
#  * mysql+pymysql://root:***@localhost/
# (pymysql.err.OperationalError) (1050, "Table 'customer' already exists")
# [SQL: CREATE TABLE Customer ( CustomerID INT AUTO_INCREMENT PRIMARY KEY, FirstName VARCHAR(100), LastName VARCHAR(100), Email VARCHAR(255), Phone VARCHAR(20), BillingAddress TEXT, ShippingAddress TEXT, CustomerSince DATE, IsActive BOOLEAN );]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#  * mysql+pymysql://root:***@localhost/
# (pymysql.err.OperationalError) (1050, "Table 'salesorder' already exists")
# [SQL: CREATE TABLE SalesOrder ( SalesOrderID INT AUTO_INCREMENT PRIMARY KEY, CustomerID INT, OrderDate DATE, RequiredDate DATE, ShippedDate DATE, Status VARCHAR(50), Comments TEXT, PaymentMethod VARCHAR(50), IsPaid BOOLEAN, FOREIGN KEY (CustomerID) REFERENCES Customer(CustomerID) );]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#  * mysql+pymysql://root:***@localhost/
# ...

# %%
# %sql CREATE TABLE LineItem ( \
  LineItemID INT AUTO_INCREMENT PRIMARY KEY, \
  SalesOrderID INT, \
  ProductID INT, \
  Quantity INT, \
  UnitPrice DECIMAL(10, 2), \
  Discount DECIMAL(10, 2), \
  TotalPrice DECIMAL(10, 2), \
  FOREIGN KEY (SalesOrderID) REFERENCES SalesOrder(SalesOrderID), \
  FOREIGN KEY (ProductID) REFERENCES Product(ProductID) \
);

# %sql CREATE TABLE Employee ( \
  EmployeeID INT AUTO_INCREMENT PRIMARY KEY, \
  FirstName VARCHAR(100), \
  LastName VARCHAR(100), \
  Email VARCHAR(255), \
  Phone VARCHAR(20), \
  HireDate DATE, \
  Position VARCHAR(100), \
  Salary DECIMAL(10, 2) \
);

# %sql CREATE TABLE Supplier ( \
  SupplierID INT AUTO_INCREMENT PRIMARY KEY, \
  CompanyName VARCHAR(255), \
  ContactName VARCHAR(100), \
  ContactTitle VARCHAR(50), \
  Address TEXT, \
  Phone VARCHAR(20), \
  Email VARCHAR(255) \
);

# %sql CREATE TABLE InventoryLog ( \
  LogID INT AUTO_INCREMENT PRIMARY KEY, \
  ProductID INT, \
  ChangeDate DATE, \
  QuantityChange INT, \
  Notes TEXT, \
  FOREIGN KEY (ProductID) REFERENCES Product(ProductID) \
);
# Out:
#  * mysql+pymysql://root:***@localhost/
# (pymysql.err.OperationalError) (1050, "Table 'lineitem' already exists")
# [SQL: CREATE TABLE LineItem ( LineItemID INT AUTO_INCREMENT PRIMARY KEY, SalesOrderID INT, ProductID INT, Quantity INT, UnitPrice DECIMAL(10, 2), Discount DECIMAL(10, 2), TotalPrice DECIMAL(10, 2), FOREIGN KEY (SalesOrderID) REFERENCES SalesOrder(SalesOrderID), FOREIGN KEY (ProductID) REFERENCES Product(ProductID) );]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#  * mysql+pymysql://root:***@localhost/
# (pymysql.err.OperationalError) (1050, "Table 'employee' already exists")
# [SQL: CREATE TABLE Employee ( EmployeeID INT AUTO_INCREMENT PRIMARY KEY, FirstName VARCHAR(100), LastName VARCHAR(100), Email VARCHAR(255), Phone VARCHAR(20), HireDate DATE, Position VARCHAR(100), Salary DECIMAL(10, 2) );]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#  * mysql+pymysql://root:***@localhost/
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Create connection
engine = create_engine('mysql+pymysql://root:Chicago_2145@localhost/')

# Run query
query = """
SELECT TABLE_NAME, COLUMN_NAME, DATA_TYPE, IS_NULLABLE, COLUMN_DEFAULT, CHARACTER_MAXIMUM_LENGTH 
FROM INFORMATION_SCHEMA.COLUMNS 
WHERE TABLE_SCHEMA = 'SalesOrderSchema' 
ORDER BY TABLE_NAME, ORDINAL_POSITION;
"""
df = pd.read_sql(query, engine)
df
# Out:
#       TABLE_NAME      COLUMN_NAME DATA_TYPE IS_NULLABLE COLUMN_DEFAULT  \
# 0       Customer       CustomerID       int          NO           None
# 1       Customer        FirstName   varchar         YES           None
# 2       Customer         LastName   varchar         YES           None
# 3       Customer            Email   varchar         YES           None
# 4       Customer            Phone   varchar         YES           None
# 5       Customer   BillingAddress      text         YES           None
# 6       Customer  ShippingAddress      text         YES           None
# 7       Customer    CustomerSince      date         YES           None
# 8       Customer         IsActive   tinyint         YES           None
# 9       Employee       EmployeeID       int          NO           None
# 10      Employee        FirstName   varchar         YES           None
# 11      Employee         LastName   varchar         YES           None
# ...
